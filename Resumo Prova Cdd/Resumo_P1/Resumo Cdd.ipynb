# %% [markdown]
# # Resumo Prova Ciência dos Dados

# %% [markdown]
# ## Aula 02

# %% [markdown]
# Variáveis:
#
# ### Qualititiva
#
# ``Nominais:``
# Não é possível estabelecer uma ordem natural entre os valores.
# Ex.: Sexos M e F, Turmas A e B
#
# ``Ordinais``
# É possível estabecer ordem natural.
# Ex.: Pequeno/Médio/Grande, Classes baixa, média, alta
#
#
# ``Estratégia``
#
# • Gráficos de setor
#
# • Gráficos de barra
#
# • Tabela de frequência
#
#
# ### Quantitativa
#
# ``Discretas:``
# Provenientes de contagens
#
# Exemplos:
#
# • número de membros de uma família
#
# • número de kb de um arquivo,
#
# • número de conexões em uma rede
# ``Contínuas:``
# Provenientes de mensuração
# Exemplo: massa (kg) de um produto, comprimento (m) de
# uma Estrada, etc
#
#
# ``Estratégia``
#
# • Histograma
# • Boxplot
# • Tabela de frequência
#
# <img src="recursos_cruzamentos.png" style="width: 400px;"/>
#
# ``Frequencia Absoluta``
# Quantas vezes uma variável aparece num espaço amostral
#
# Ex: quantas vezes cada marca de automóvel foi citada
#
# ``Frequencia Relativa``
# Dada em porcentagem sobre o total
#
# ### Boxplot
# <img src="boxplot.png" style="width: 400px;"/>
# O boxplot contém a representação dos quartis e uma noção do que são dados aberrantes (outliers). Para construi-lo:
#
# Desenhar um retângulo (azul) que representa o 1o e 3o quartis, que chamaremos de Q1 e Q3. O tamanho entre eles é chamado de intervalo interquartil ou IQ.
# Traçar uma linha (verde) dentro do retângulo que presenta a mediana (2.o quartil)
# Os limites representados pelas linhas pretas horizontais fora do retângulo representam o conjunto dos dados que está dentro do intervalo Q1-1.5IQ e Q3+1.5IQ.
# As bolinhas são os outliers ou valores atípicos. São considerados outliers todos valores fora dos limites desenhados pelo item 3 (Q1-1.5IQ e Q3+1.5IQ).
#
# ### Média, Mediana e Moda
#
# ``Média``
# <img src="media.png" style="width: 200px;"/>
#
# ``Mediana``
# Mediana é o valor que divide um conjunto de dados ordenados ao meio. (não é afetada por dados extremos como a média)
# <img src="mediana.png" style="width: 400px;"/>
#
# ``Moda``
# Valor que mais aparece em um conjunto de dados.
#
# ### Assimetrias
# <img src="assimetria_1.jpg" style="width: 400px;"/>
#
# <img src="assimetria_2.jpg" style="width: 400px;"/>
# A distribuição (a) é simétrica porque a média “coincide” com a mediana e a moda.
#
# A distribuição (b) é assimétrica à direita porque a moda é menor que a mediana, que, por sua vez, é menor que a média aritmética.
#
# A distribuição (c) é assimétrica à esquerda porque a média aritmética é menor que a mediana que, por sua vez, é menor que a moda.
#
# ### Medidas de dispersão
#
# ``Variância``
# Uma medida de dispersão que mostra quão distantes os valores estão da média (distorcida por estar ao quadrado)
# <img src="variancia.png" style="width: 400px;"/>
#
# ``Desvio Padrão``
# O valor do desvio padrão pode crescer dramaticamente com a inclusão de um ou mais outliers. Diminui a distorção da variância.
# <img src="desvio_padrao.png" style="width: 400px;"/>
#
#
# ### Percentil ou Quantil
# <img src="percentil.png" style="width: 400px;"/>
# Quantil ou Percentil de ordem p (0<p<100): é o valor que
# divide o conjunto de dados ordenado em 2 partes: uma
# delas com p% dos menores valores e a outra com (100-p)%
# dos maiores valores.

# %% [markdown]
# ## Aula 02

# %% [markdown]
# ### Covariância
# A covariância mede a relação linear entre duas variáveis.
# <img src="covariancia.jpg" style="width: 400px;"/>

# %% [markdown]
# ## Aula 06 e 07

# %% [markdown]
# ### União
# <img src="uniao.png" style="width: 400px;"/>
# ### Intersecção
# <img src="interseccao.png" style="width: 400px;"/>
# ### Probabilidade Condicional P(A|B)
# <img src="condicional.png" style="width: 400px;"/>
# ### Bayes
# <img src="bayes.png" style="width: 400px;"/>

# %% [markdown]
# ## Aula 08

# %% [markdown]
# ### Variáveis Aleatórias Discretas
# conjunto de possibilidades
# é um conjunto finito ou enumerável
#
# ``Exemplo:``
#
# • Número de filhos, número de salas de aula
#
# • Número de benefícios do Bolsa Família por família
#
# ### Variáveis Aleatórias Contínuas
# conjunto de possibilidades
# num intervalo ou conjuntos de intervalos contínuos
#
# ``Exemplo:``
#
# • tempo de duração
#
# • temperatura
#
# ### Esperança
# <img src="esperanca.png" style="width: 400px;"/>

# %% [markdown]
# ## Aula 09 e 10

# %% [markdown]
# ### Bernoulli
# Experimento que tem apenas dois resultados
# possíveis.
# <img src="bernoulli.png" style="width: 400px;"/>
#
# ### Binomial
# Experimento usado quando Bernoulli é repetido ``n`` vezes, com ``y`` elementos tendendo ao sucesso.  Sendo ``p`` a probabilidade de sucesso.
# <img src="binomial.png" style="width: 400px;"/>
# <img src="binomial_2.png" style="width: 400px;"/>
#
# ### Poisson
# Estimativa do número de ocorrências (discretas) num espaço
# contínuo
#
# ``Exemplo:``
#
# • Número de aviões que decolam numa hora
#
# • Número de usuários conectados no Facebook por minuto
#
# • Número de acidentes em 100 km de uma rodovia
#
# • Número de clientes na fila por minuto (teoria das filas)
#
# • Consumo de um produto em um mês (gestão de estoques)
#
# ``Propriedades (suposições):``
#
# ✓ Probabilidade de uma ocorrência é a mesma para dois
# intervalos quaisquer de igual tamanho.
#
# ✓ A ocorrência ou não num dado intervalo é
# independente da ocorrência ou não em outro intervalo.
#
# <img src="poisson.png" style="width: 400px;"/>
#
# 𝐄(X) = 𝐕𝐚𝐫 𝐗 = λ
#
#
# <img src="exemplo_poisson.png" style="width: 400px;"/>

# %% [markdown]
# ## Aula 11 e 12

# %% [markdown]
# ### Função Densidade de Probabilidade (fdp-pt_br | pdf-en_us)
# Da a probabilidade de uma área normalizada.
# <img src="fdp.png" style="width: 400px;"/>
# <img src="fdp_2.png" style="width: 400px;"/>
#
# ``Python``: Plota Gráfico
# ### Função de Distribuição Acumulada (fda-pt_br | cdf-en_us)
# ``Python``: Input: Ponto Output: Probabilidade naquele ponto
#
# ### Função de Distribuição Acumulada (ppf-en_us)
# ``Python``: Input: Probabilidade Output: onde está o ponto
#
# ### Distribuição Uniforme
# ``Python``: Probabilidade em um determinado ponto
# <img src="uniforme.png" style="width: 400px;"/>
#
# ### Distribuição Exponencial
# Usada para modelagem de tempos de
# espera
# ``Python``: Probabilidade em um determinado ponto
# <img src="exponencial.png" style="width: 400px;"/>
# <img src="exponencial_2.png" style="width: 400px;"/>
# <img src="integrais.png" style="width: 400px;"/>

# %% [markdown]
# ## Aula 13

# %% [markdown]
# ### Normal

# %% [markdown]
# <img src="normal.png" style="width: 400px;"/>
# <img src="normal_2.png" style="width: 400px;"/>
# Para calcular a probabilidade de uma área normalizada temos que usar de Z e olhar seu valor na tabela fornecida
# <img src="area_normal.png" style="width: 400px;"/>

# %% [markdown]
# # Códigos

# %% [markdown]
# ## Análise
#
# <img src="describe.png" style="width: 400px;"/>
#
#
# ## Covariância
# covariancia = correlaçao de -1 a 1 de variaveis quantitativas
#
# ``Código:``
#
# df['Magnitude Error'].corr(df["Depth"])
#
# ## Binomial
#
# ``Exemplo:``
#
# (Se usa quando por exemplo, quando se tem uma amostra, pergunta-se a probabilidade de x amostras participarem do evento, dada uma certa taxa)
#
# - distr.binom(y;n;p;0)
# - distribuiçao binomial
# - P(Y=y) = stats.binom.pmf(y,n,p)
# - P(Y>=y) = stats.binom.cdf(y,n,p)
# - E(y), Var(X) = stats.binom.stats(n;p; moments = 'mv')
# - P(Y<=y) = 1- P(Y<y)
# - Var(X) = np(1-p)
#
# ## Poisson
#
# ``Código:``
#
# stats.poisson.pmf(x,lamba)
#
# ``Exemplo:``
#
# - x = 0
# - lamba = 5
# - p_0 = stats.poisson.pmf(x,lamba)
#
# ## pdf
#
# Input: dado Output: Gráfico Normalizado
#
# ``Código:``
#
# plt.plot(dado, stats.norm.pdf(x, loc=media(mean()), scale=dp(std())), lw=3, alpha=0.6)
#
# ``Exemplo:``
#
# - x = sorted(data2013.official)
# - m = data2013.official.mean()
# - dp = data2013.official.std()
# - plot = data2013.official.plot.hist(title='Probabilidade dos Tempos oficiais', alpha=0.7,label='tempo', -normed=1)
# - plt.ylabel('Densidade')
# - plt.xlabel('Tempo oficial')
# - plt.legend()
# - plt.plot(x, stats.norm.pdf(x, loc=m, scale=dp), lw=3, alpha=0.6)
#
# ## ppf
#
# Python: Input: Probabilidade Output: onde está o ponto
#
# ``Código:``
#
# stats.norm.ppf(probabilidade, loc=m, scale=dp)
#
# ``Exemplo:``
# - stats.norm.ppf(0.8, loc=m, scale=dp)
#
# ## cdf
# Input: Ponto Output: Probabilidade
#
# ``Código:``
#
# stats.norm.cdf(valor_do_ponto, loc=m, scale=dp)
#
# ``Exemplo``:
# - stats.norm.cdf(220, loc=m, scale=dp)
#
# ## Reta de Disperção
#
# ``Código:``
#
# def reta(dados_x, dados_y):
#     a = dados_y.cov(dados_x) / dados_x.var()
#     b = dados_y.mean() - a*dados_x.mean()
#
#     print('Ajuste linear entre X3 e X4:')
#     print('Coeficiente linear:', b)
#     print('Coeficiente angular:', a)
#
#     fig = plt.figure(figsize=(8, 6))
#     plt.scatter(dados_x, dados_y, c='red', alpha=0.8)
#     plt.title('x versus y')
#     plt.xlabel('eixo x')
#     plt.ylabel('eixo y')
#
#     plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color='blue')
#
#     plt.tight_layout()
#     plt.show()
